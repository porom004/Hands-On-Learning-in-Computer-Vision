# %% [markdown]
# [![Labellerr](https://storage.googleapis.com/labellerr-cdn/%200%20Labellerr%20template/notebook.webp)](https://www.labellerr.com)
#
# # **Fine-Tune RT-DETR for Livestock Monitoring**
#
# ---
#
# [![labellerr](https://img.shields.io/badge/Labellerr-BLOG-black.svg)](https://www.labellerr.com/blog)
# [![Youtube](https://img.shields.io/badge/Labellerr-YouTube-b31b1b.svg)](https://www.youtube.com/@Labellerr)
# [![Github](https://img.shields.io/badge/Labellerr-GitHub-green.svg)](https://github.com/Labellerr/Hands-On-Learning-in-Computer-Vision)

# %% [markdown]
# ## Overview
# End-to-end pipeline for **livestock detection and tracking** using RT-DETR (Real-Time Detection Transformer).
#
# ## Workflow
# 1. **Data Preparation**: Extract frames → Convert COCO to YOLO → Split dataset (70/10/10)
# 2. **Model Training**: RT-DETR-L model, 100 epochs, 640x640 images
# 3. **Inference**: Track livestock in videos with trained model
# 4. **Custom Tracker**: LivestockMonitor class with unique colors per animal + live count
#
# ## Technologies
# PyTorch • Ultralytics RT-DETR • OpenCV • NumPy

# %% [markdown]
# ## Setup: Import Required Libraries
# Import all necessary libraries for computer vision, deep learning, and data manipulation:
# - **OpenCV (cv2)**: Image and video processing
# - **NumPy**: Numerical operations
# - **Ultralytics**: YOLO/RT-DETR framework
# - **PyTorch**: Deep learning backend
# - **Pathlib**: File path handling

# %%
import cv2
import numpy as np
from ultralytics import RTDETR
import torch
from typing import Dict, Tuple, Optional, List
from pathlib import Path
import random 
# %matplotlib inline

# %% [markdown]
# ## Setup: Clone YOLO Fine-tuning Utilities
# Clone the `yolo_finetune_utils` repository which contains helper functions for:
# - Frame extraction from videos
# - COCO to YOLO format conversion
# - Dataset preparation utilities
# > **Note**: Uncomment this cell only if you haven't cloned the repository yet.

# %%
# !git clone https://github.com/Labellerr/yolo_finetune_utils.git

# %% [markdown]
# ## Data Preparation: Extract Random Frames from Videos
# Extract random frames from video files to create a dataset for annotation.
# **Parameters**:
# - `paths`: List of video directories
# - `total_images`: Number of frames to extract
# - `out_dir`: Output directory for extracted frames
# - `jpg_quality`: JPEG compression quality (100 = highest)
# - `seed`: Random seed for reproducibility

# %%
from yolo_finetune_utils.frame_extractor import extract_random_frames

extract_random_frames(
        paths=[r"videos\manufacturing_video_data"],
        total_images=150,
        out_dir="dataset_frames",
        jpg_quality=100,
        seed=42
    )

# %% [markdown]
# ## Data Preparation: Convert Annotations to YOLO Format
# Convert COCO-format annotations to YOLO format and split the dataset into train/val/test sets.
# **Configuration**:
# - **Train/Val/Test Split**: 70% / 10% / 10%
# - **Input**: COCO JSON annotations + image directory
# - **Output**: YOLO-format dataset in `model_dataset/`
# The converter automatically:
# - Creates train/val/test splits
# - Generates YOLO-format label files (.txt)
# - Organizes images and labels into proper directory structure

# %%
from yolo_finetune_utils.coco_yolo_converter.seg_converter import coco_to_yolo_converter

ANNOTATION_JSON = "annotations.json"
IMAGE_DIR = "dataset_frames"


coco_to_yolo_converter(
        json_path=ANNOTATION_JSON,
        images_dir=IMAGE_DIR,
        output_dir="model_dataset",
        use_split=True,
        train_ratio=0.7,
        val_ratio=0.1,
        test_ratio=0.1,
        shuffle=True,
        verbose=False
    )

# %% [markdown]
# ## System Check: GPU Memory Status
# Clear GPU cache and display current memory usage to ensure sufficient resources for training.
# **Memory Metrics**:
# - **Allocated**: Currently used GPU memory
# - **Cached**: Reserved but not actively used
# - **Free**: Available GPU memory
# > Run this cell before training to free up GPU memory.

# %%
import torch
torch.cuda.empty_cache()

# Check GPU memory status
print(f"Allocated: {torch.cuda.memory_allocated(0)/1024**3:.2f} GB")
print(f"Cached: {torch.cuda.memory_reserved(0)/1024**3:.2f} GB")
print(f"Free: {torch.cuda.mem_get_info(0)[0]/1024**3:.2f} GB")
# Out:
# Allocated: 0.40 GB
# Cached: 0.43 GB
# Free: 6.41 GB

# %% [markdown]
# ## Model Training: RT-DETR for Livestock Detection
# Train the RT-DETR-L (Large) model on the livestock dataset.
# **Training Configuration**:
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | `data` | `model_dataset/data.yaml` | Dataset configuration file |
# | `epochs` | 100 | Number of training epochs |
# | `imgsz` | 640 | Input image size (640x640) |
# | `batch` | 4 | Batch size |
# | `device` | 0 | GPU device ID (0 = first GPU) |
# | `workers` | 1 | Number of dataloader workers |
# **Model**: RT-DETR-L (Large variant)
# - Pre-trained weights: `rtdetr-l.pt`
# - Architecture: Real-Time Detection Transformer
# - Optimized for real-time object detection
# > **Training Time**: Approximately 30-60 minutes depending on GPU

# %%
from ultralytics import RTDETR
# Load a model
model = RTDETR("rtdetr-l.pt")

# Train the model
results = model.train(
    data=r"model_dataset\data.yaml",    # Path to your dataset YAML file
    epochs=100,                        # Number of training epochs
    imgsz=640,                         # Image size
    batch=4,                          # Batch size
    device=0,                          # GPU device (0 for first GPU, 'cpu' for CPU)
    workers=1                          # Number of dataloader workers
)

# %% [markdown]
# ## Inference: Track Livestock in Video
# Run the trained RT-DETR model on a sample video to detect and track livestock.
# **Inference Configuration**:
# - **Model**: Best weights from training (`runs/detect/train/weights/best.pt`)
# - **Confidence Threshold**: 0.5 (50%)
# - **IOU Threshold**: 0.5 for NMS (Non-Maximum Suppression)
# - **Tracking**: Enabled with `track()` method
# - **Labels**: Hidden (`show_labels=False`)
# **Output**:
# - Tracked video saved to `runs/detect/track*/`
# - Each frame shows detected cows with bounding boxes
# - Real-time inference speed displayed per frame

# %%
from ultralytics import RTDETR

model = RTDETR(r"runs\detect\train\weights\best.pt")


video_sample = r"livestocks_sample_video\sample2.mp4"
results = model.track(video_sample, conf=0.5, save=True, show_labels=False, stream=True, nms=True, iou=0.5)

for result in results:
    pass
# Out:
# video 1/1 (frame 1/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 63.4ms
# video 1/1 (frame 2/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 139.2ms
# video 1/1 (frame 3/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 33.4ms
# video 1/1 (frame 4/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 34.4ms
# video 1/1 (frame 5/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 30.6ms
# video 1/1 (frame 6/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 33.1ms
# video 1/1 (frame 7/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 37.1ms
# video 1/1 (frame 8/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 31.4ms
# video 1/1 (frame 9/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 33.0ms
# video 1/1 (frame 10/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 31.6ms
# video 1/1 (frame 11/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 33.5ms
# video 1/1 (frame 12/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 32.6ms
# video 1/1 (frame 13/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 31.5ms
# video 1/1 (frame 14/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 31.3ms
# video 1/1 (frame 15/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 29.6ms
# video 1/1 (frame 16/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 30.7ms
# video 1/1 (frame 17/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 32.6ms
# video 1/1 (frame 18/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 32.0ms
# video 1/1 (frame 19/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.3ms
# video 1/1 (frame 20/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.1ms
# video 1/1 (frame 21/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 29.6ms
# video 1/1 (frame 22/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 31.9ms
# video 1/1 (frame 23/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 32.9ms
# video 1/1 (frame 24/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 29.9ms
# video 1/1 (frame 25/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 30.8ms
# video 1/1 (frame 26/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 28.7ms
# video 1/1 (frame 27/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 31.1ms
# video 1/1 (frame 28/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 30.3ms
# video 1/1 (frame 29/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 41 Cows, 29.1ms
# video 1/1 (frame 30/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.3ms
# video 1/1 (frame 31/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.3ms
# video 1/1 (frame 32/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 31.1ms
# video 1/1 (frame 33/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 31.0ms
# video 1/1 (frame 34/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.9ms
# video 1/1 (frame 35/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.5ms
# video 1/1 (frame 36/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 25.6ms
# video 1/1 (frame 37/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 28.6ms
# video 1/1 (frame 38/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.3ms
# video 1/1 (frame 39/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.6ms
# video 1/1 (frame 40/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 33.3ms
# video 1/1 (frame 41/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 42/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.9ms
# video 1/1 (frame 43/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 210.2ms
# video 1/1 (frame 44/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 166.5ms
# video 1/1 (frame 45/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 190.9ms
# video 1/1 (frame 46/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 168.2ms
# video 1/1 (frame 47/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 226.8ms
# video 1/1 (frame 48/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 190.8ms
# video 1/1 (frame 49/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 148.3ms
# video 1/1 (frame 50/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 188.2ms
# video 1/1 (frame 51/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 153.9ms
# video 1/1 (frame 52/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 161.6ms
# video 1/1 (frame 53/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 168.7ms
# video 1/1 (frame 54/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 175.6ms
# video 1/1 (frame 55/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 150.8ms
# video 1/1 (frame 56/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 163.8ms
# video 1/1 (frame 57/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 169.6ms
# video 1/1 (frame 58/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 153.9ms
# video 1/1 (frame 59/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 167.2ms
# video 1/1 (frame 60/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 204.2ms
# video 1/1 (frame 61/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 163.8ms
# video 1/1 (frame 62/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 166.9ms
# video 1/1 (frame 63/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 163.9ms
# video 1/1 (frame 64/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 181.4ms
# video 1/1 (frame 65/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 184.3ms
# video 1/1 (frame 66/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 171.5ms
# video 1/1 (frame 67/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 159.2ms
# video 1/1 (frame 68/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 158.0ms
# video 1/1 (frame 69/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 169.5ms
# video 1/1 (frame 70/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 169.1ms
# video 1/1 (frame 71/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 141.0ms
# video 1/1 (frame 72/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 167.6ms
# video 1/1 (frame 73/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 174.6ms
# video 1/1 (frame 74/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 166.0ms
# video 1/1 (frame 75/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 171.5ms
# video 1/1 (frame 76/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 177.0ms
# video 1/1 (frame 77/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 165.7ms
# video 1/1 (frame 78/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 187.2ms
# video 1/1 (frame 79/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 169.8ms
# video 1/1 (frame 80/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 160.8ms
# video 1/1 (frame 81/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 206.0ms
# video 1/1 (frame 82/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 144.0ms
# video 1/1 (frame 83/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 170.9ms
# video 1/1 (frame 84/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 191.7ms
# video 1/1 (frame 85/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 257.1ms
# video 1/1 (frame 86/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 160.6ms
# video 1/1 (frame 87/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 165.6ms
# video 1/1 (frame 88/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 139.4ms
# video 1/1 (frame 89/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 148.3ms
# video 1/1 (frame 90/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 150.3ms
# video 1/1 (frame 91/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 159.3ms
# video 1/1 (frame 92/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 191.7ms
# video 1/1 (frame 93/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 207.3ms
# video 1/1 (frame 94/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 184.0ms
# video 1/1 (frame 95/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 197.3ms
# video 1/1 (frame 96/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 130.2ms
# video 1/1 (frame 97/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 155.4ms
# video 1/1 (frame 98/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 160.8ms
# video 1/1 (frame 99/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 154.7ms
# video 1/1 (frame 100/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.7ms
# video 1/1 (frame 101/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.9ms
# video 1/1 (frame 102/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.5ms
# video 1/1 (frame 103/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.1ms
# video 1/1 (frame 104/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.4ms
# video 1/1 (frame 105/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.7ms
# video 1/1 (frame 106/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.5ms
# video 1/1 (frame 107/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.9ms
# video 1/1 (frame 108/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.1ms
# video 1/1 (frame 109/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.9ms
# video 1/1 (frame 110/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.9ms
# video 1/1 (frame 111/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.0ms
# video 1/1 (frame 112/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.3ms
# video 1/1 (frame 113/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 28.8ms
# video 1/1 (frame 114/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 28.8ms
# video 1/1 (frame 115/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 31.5ms
# video 1/1 (frame 116/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 26.9ms
# video 1/1 (frame 117/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.1ms
# video 1/1 (frame 118/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.2ms
# video 1/1 (frame 119/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.6ms
# video 1/1 (frame 120/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.8ms
# video 1/1 (frame 121/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 33.3ms
# video 1/1 (frame 122/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 33.2ms
# video 1/1 (frame 123/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.6ms
# video 1/1 (frame 124/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 26.4ms
# video 1/1 (frame 125/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.6ms
# video 1/1 (frame 126/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.7ms
# video 1/1 (frame 127/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.5ms
# video 1/1 (frame 128/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.7ms
# video 1/1 (frame 129/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.5ms
# video 1/1 (frame 130/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.0ms
# video 1/1 (frame 131/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.1ms
# video 1/1 (frame 132/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.9ms
# video 1/1 (frame 133/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 25.5ms
# video 1/1 (frame 134/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.1ms
# video 1/1 (frame 135/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.3ms
# video 1/1 (frame 136/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.7ms
# video 1/1 (frame 137/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 35.0ms
# video 1/1 (frame 138/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.6ms
# video 1/1 (frame 139/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.0ms
# video 1/1 (frame 140/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.9ms
# video 1/1 (frame 141/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.7ms
# video 1/1 (frame 142/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.9ms
# video 1/1 (frame 143/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.5ms
# video 1/1 (frame 144/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.1ms
# video 1/1 (frame 145/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.0ms
# video 1/1 (frame 146/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.2ms
# video 1/1 (frame 147/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.3ms
# video 1/1 (frame 148/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.7ms
# video 1/1 (frame 149/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 150/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 31.1ms
# video 1/1 (frame 151/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.5ms
# video 1/1 (frame 152/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.2ms
# video 1/1 (frame 153/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.1ms
# video 1/1 (frame 154/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.7ms
# video 1/1 (frame 155/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.2ms
# video 1/1 (frame 156/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 32.8ms
# video 1/1 (frame 157/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 34.2ms
# video 1/1 (frame 158/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.5ms
# video 1/1 (frame 159/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.1ms
# video 1/1 (frame 160/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.3ms
# video 1/1 (frame 161/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.8ms
# video 1/1 (frame 162/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.2ms
# video 1/1 (frame 163/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 164/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 33.7ms
# video 1/1 (frame 165/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.2ms
# video 1/1 (frame 166/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 31.7ms
# video 1/1 (frame 167/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.9ms
# video 1/1 (frame 168/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.8ms
# video 1/1 (frame 169/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.8ms
# video 1/1 (frame 170/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.8ms
# video 1/1 (frame 171/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.5ms
# video 1/1 (frame 172/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.6ms
# video 1/1 (frame 173/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.1ms
# video 1/1 (frame 174/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.5ms
# video 1/1 (frame 175/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.1ms
# video 1/1 (frame 176/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 177/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.1ms
# video 1/1 (frame 178/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.5ms
# video 1/1 (frame 179/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.1ms
# video 1/1 (frame 180/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.5ms
# video 1/1 (frame 181/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.7ms
# video 1/1 (frame 182/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 183/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.5ms
# video 1/1 (frame 184/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.6ms
# video 1/1 (frame 185/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 25.7ms
# video 1/1 (frame 186/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.2ms
# video 1/1 (frame 187/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.3ms
# video 1/1 (frame 188/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.3ms
# video 1/1 (frame 189/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.9ms
# video 1/1 (frame 190/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.7ms
# video 1/1 (frame 191/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.0ms
# video 1/1 (frame 192/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.8ms
# video 1/1 (frame 193/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.1ms
# video 1/1 (frame 194/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.3ms
# video 1/1 (frame 195/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.8ms
# video 1/1 (frame 196/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.5ms
# video 1/1 (frame 197/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.4ms
# video 1/1 (frame 198/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.1ms
# video 1/1 (frame 199/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.9ms
# video 1/1 (frame 200/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.1ms
# video 1/1 (frame 201/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.2ms
# video 1/1 (frame 202/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.4ms
# video 1/1 (frame 203/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.6ms
# video 1/1 (frame 204/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.9ms
# video 1/1 (frame 205/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.9ms
# video 1/1 (frame 206/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.6ms
# video 1/1 (frame 207/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 30.8ms
# video 1/1 (frame 208/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.8ms
# video 1/1 (frame 209/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.9ms
# video 1/1 (frame 210/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.4ms
# video 1/1 (frame 211/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.4ms
# video 1/1 (frame 212/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.3ms
# video 1/1 (frame 213/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.8ms
# video 1/1 (frame 214/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.6ms
# video 1/1 (frame 215/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.1ms
# video 1/1 (frame 216/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.7ms
# video 1/1 (frame 217/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.9ms
# video 1/1 (frame 218/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.2ms
# video 1/1 (frame 219/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 30.6ms
# video 1/1 (frame 220/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.8ms
# video 1/1 (frame 221/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.0ms
# video 1/1 (frame 222/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.1ms
# video 1/1 (frame 223/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.4ms
# video 1/1 (frame 224/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.1ms
# video 1/1 (frame 225/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 33.0ms
# video 1/1 (frame 226/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.6ms
# video 1/1 (frame 227/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.5ms
# video 1/1 (frame 228/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.0ms
# video 1/1 (frame 229/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.9ms
# video 1/1 (frame 230/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.7ms
# video 1/1 (frame 231/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.1ms
# video 1/1 (frame 232/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.7ms
# video 1/1 (frame 233/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.9ms
# video 1/1 (frame 234/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.0ms
# video 1/1 (frame 235/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 26.2ms
# video 1/1 (frame 236/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.1ms
# video 1/1 (frame 237/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.9ms
# video 1/1 (frame 238/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.9ms
# video 1/1 (frame 239/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 30.0ms
# video 1/1 (frame 240/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 31.7ms
# video 1/1 (frame 241/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 30.2ms
# video 1/1 (frame 242/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.6ms
# video 1/1 (frame 243/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.0ms
# video 1/1 (frame 244/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.6ms
# video 1/1 (frame 245/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.4ms
# video 1/1 (frame 246/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.5ms
# video 1/1 (frame 247/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 25.8ms
# video 1/1 (frame 248/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.1ms
# video 1/1 (frame 249/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.6ms
# video 1/1 (frame 250/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.7ms
# video 1/1 (frame 251/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 30.4ms
# video 1/1 (frame 252/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.4ms
# video 1/1 (frame 253/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.0ms
# video 1/1 (frame 254/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.0ms
# video 1/1 (frame 255/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.8ms
# video 1/1 (frame 256/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.9ms
# video 1/1 (frame 257/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.2ms
# video 1/1 (frame 258/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.7ms
# video 1/1 (frame 259/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.5ms
# video 1/1 (frame 260/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.0ms
# video 1/1 (frame 261/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 32.3ms
# video 1/1 (frame 262/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.7ms
# video 1/1 (frame 263/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 27.8ms
# video 1/1 (frame 264/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 25.4ms
# video 1/1 (frame 265/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.5ms
# video 1/1 (frame 266/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.4ms
# video 1/1 (frame 267/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.8ms
# video 1/1 (frame 268/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.1ms
# video 1/1 (frame 269/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.8ms
# video 1/1 (frame 270/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 27.6ms
# video 1/1 (frame 271/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.5ms
# video 1/1 (frame 272/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.0ms
# video 1/1 (frame 273/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.0ms
# video 1/1 (frame 274/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.2ms
# video 1/1 (frame 275/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.5ms
# video 1/1 (frame 276/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.3ms
# video 1/1 (frame 277/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.0ms
# video 1/1 (frame 278/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.8ms
# video 1/1 (frame 279/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.4ms
# video 1/1 (frame 280/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.8ms
# video 1/1 (frame 281/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.2ms
# video 1/1 (frame 282/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.4ms
# video 1/1 (frame 283/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.2ms
# video 1/1 (frame 284/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.6ms
# video 1/1 (frame 285/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 29.6ms
# video 1/1 (frame 286/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 27.9ms
# video 1/1 (frame 287/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 42 Cows, 27.6ms
# video 1/1 (frame 288/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.6ms
# video 1/1 (frame 289/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 30.3ms
# video 1/1 (frame 290/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.6ms
# video 1/1 (frame 291/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 33.6ms
# video 1/1 (frame 292/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.6ms
# video 1/1 (frame 293/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 31.7ms
# video 1/1 (frame 294/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.2ms
# video 1/1 (frame 295/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 25.6ms
# video 1/1 (frame 296/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.0ms
# video 1/1 (frame 297/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.5ms
# video 1/1 (frame 298/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.6ms
# video 1/1 (frame 299/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.9ms
# video 1/1 (frame 300/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 25.9ms
# video 1/1 (frame 301/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.8ms
# video 1/1 (frame 302/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 28.8ms
# video 1/1 (frame 303/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 27.7ms
# video 1/1 (frame 304/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.6ms
# video 1/1 (frame 305/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.2ms
# video 1/1 (frame 306/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.6ms
# video 1/1 (frame 307/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 43 Cows, 26.3ms
# video 1/1 (frame 308/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.9ms
# video 1/1 (frame 309/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 27.4ms
# video 1/1 (frame 310/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.2ms
# video 1/1 (frame 311/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.6ms
# video 1/1 (frame 312/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.8ms
# video 1/1 (frame 313/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 31.2ms
# video 1/1 (frame 314/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 28.8ms
# video 1/1 (frame 315/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 29.2ms
# video 1/1 (frame 316/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.6ms
# video 1/1 (frame 317/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 44 Cows, 26.3ms
# video 1/1 (frame 318/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.9ms
# video 1/1 (frame 319/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 29.2ms
# video 1/1 (frame 320/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 28.9ms
# video 1/1 (frame 321/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 26.3ms
# video 1/1 (frame 322/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 32.0ms
# video 1/1 (frame 323/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.6ms
# video 1/1 (frame 324/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.3ms
# video 1/1 (frame 325/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 30.0ms
# video 1/1 (frame 326/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 27.3ms
# video 1/1 (frame 327/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 31.6ms
# video 1/1 (frame 328/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 26.3ms
# video 1/1 (frame 329/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.0ms
# video 1/1 (frame 330/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.7ms
# video 1/1 (frame 331/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.6ms
# video 1/1 (frame 332/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 27.6ms
# video 1/1 (frame 333/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 30.3ms
# video 1/1 (frame 334/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 29.5ms
# video 1/1 (frame 335/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 30.1ms
# video 1/1 (frame 336/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 26.3ms
# video 1/1 (frame 337/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 25.8ms
# video 1/1 (frame 338/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.0ms
# video 1/1 (frame 339/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 26.8ms
# video 1/1 (frame 340/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 28.0ms
# video 1/1 (frame 341/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 46 Cows, 28.4ms
# video 1/1 (frame 342/342) d:\Professional\Projects\Livestock_monitoring\livestocks_sample_video\sample2.mp4: 640x640 45 Cows, 28.9ms
# Speed: 6.8ms preprocess, 53.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to D:\Professional\Projects\Livestock_monitoring\runs\detect\track5

# %% [markdown]
# ## Advanced Tracking: LivestockMonitor Class
# Define a custom `LivestockMonitor` class for enhanced livestock tracking with the following features:
# ### Key Features:
# 1. **Unique Color Assignment**: Each tracked animal gets a persistent random color
# 2. **Livestock Counter**: Real-time count displayed in upper-right corner
# 3. **Configurable Parameters**: Adjustable confidence, IOU, and visualization settings
# 4. **Class-based Architecture**: Reusable and maintainable code structure
# ### Class Methods:
# - `__init__()`: Initialize tracker with model and parameters
# - `generate_random_color()`: Create vivid random colors for tracks
# - `get_track_color()`: Retrieve or assign color for track ID
# - `draw_counter()`: Display livestock count overlay
# - `draw_detections()`: Draw bounding boxes without labels
# - `process_frame()`: Process single frame with tracking
# - `track_video()`: Track livestock in entire video file
# - `set_counter_style()`: Customize counter appearance

# %%
class LivestockMonitor:
    """
    A class for tracking livestock in videos using RT-DETR model.
    
    Each detected livestock is assigned a unique random color that persists
    across frames. The total count of detected livestock is displayed in the
    upper right corner of each frame.
    
    Attributes:
        model: The loaded RT-DETR model instance.
        track_colors: Dictionary mapping track IDs to BGR colors.
        conf_threshold: Confidence threshold for detections.
        iou_threshold: IOU threshold for NMS.
        line_thickness: Thickness of bounding box lines.
    """
    
    def __init__(
        self,
        model_path: str = r"runs\detect\train\weights\best.pt",
        conf_threshold: float = 0.5,
        iou_threshold: float = 0.5,
        line_thickness: int = 3,
        random_seed: Optional[int] = 42
    ):
        """
        Initialize the LivestockTracker.
        
        Args:
            model_path: Path to the trained RT-DETR model weights.
            conf_threshold: Confidence threshold for detections (0.0-1.0).
            iou_threshold: IOU threshold for NMS (0.0-1.0).
            line_thickness: Thickness of bounding box lines in pixels.
            random_seed: Seed for random color generation (None for random).
        """
        self.model_path = Path(model_path)
        if not self.model_path.exists():
            raise FileNotFoundError(f"Model file not found: {model_path}")
        
        self.conf_threshold = conf_threshold
        self.iou_threshold = iou_threshold
        self.line_thickness = line_thickness
        
        # Set random seed for reproducible colors
        if random_seed is not None:
            random.seed(random_seed)
        
        # Load model
        print(f"Loading RT-DETR model from: {self.model_path}")
        self.model = RTDETR(str(self.model_path))
        
        # Dictionary to store colors for each track ID
        self.track_colors: Dict[int, Tuple[int, int, int]] = {}
        
        # Counter display settings (larger for better visibility)
        self.counter_font = cv2.FONT_HERSHEY_SIMPLEX
        self.counter_font_scale = 3.0  # Increased from 1.2
        self.counter_font_thickness = 4  # Increased from 3
        self.counter_padding = 25  # Increased from 15
    
    @staticmethod
    def generate_random_color() -> Tuple[int, int, int]:
        """
        Generate a random vivid BGR color using HSV color space.
        
        Returns:
            Tuple of (B, G, R) values.
        """
        h = random.randint(0, 179)
        s = random.randint(180, 255)
        v = random.randint(180, 255)
        
        hsv_color = np.array([[[h, s, v]]], dtype=np.uint8)
        bgr_color = cv2.cvtColor(hsv_color, cv2.COLOR_HSV2BGR)[0][0]
        return (int(bgr_color[0]), int(bgr_color[1]), int(bgr_color[2]))
    
    def get_track_color(self, track_id: int) -> Tuple[int, int, int]:
        """
        Get the color for a specific track ID, generating a new one if needed.
        
        Args:
            track_id: The unique track identifier.
        
        Returns:
            BGR color tuple for the track.
        """
        if track_id not in self.track_colors:
            self.track_colors[track_id] = self.generate_random_color()
        return self.track_colors[track_id]
    
    def reset_tracks(self):
        """Clear all stored track colors."""
        self.track_colors.clear()
    
    def draw_counter(self, frame: np.ndarray, count: int) -> np.ndarray:
        """
        Draw the livestock count in the upper right corner of the frame.
        
        Args:
            frame: Input BGR frame.
            count: Number of detected livestock.
        
        Returns:
            Frame with counter overlay.
        """
        height, width = frame.shape[:2]
        count_text = f"Livestock: {count}"
        
        # Get text size for positioning
        (text_width, text_height), baseline = cv2.getTextSize(
            count_text, 
            self.counter_font, 
            self.counter_font_scale, 
            self.counter_font_thickness
        )
        
        # Position in upper right corner with padding
        text_x = width - text_width - self.counter_padding
        text_y = text_height + self.counter_padding
        
        # Background rectangle coordinates
        bg_x1 = text_x - 15
        bg_y1 = text_y - text_height - 15
        bg_x2 = width - self.counter_padding + 15
        bg_y2 = text_y + baseline + 10
        
        # Draw semi-transparent background
        overlay = frame.copy()
        cv2.rectangle(overlay, (bg_x1, bg_y1), (bg_x2, bg_y2), (0, 0, 0), -1)
        cv2.addWeighted(overlay, 0.7, frame, 0.3, 0, frame)
        
        # Draw border around counter
        cv2.rectangle(frame, (bg_x1, bg_y1), (bg_x2, bg_y2), (255, 255, 255), 2)
        
        # Draw count text
        cv2.putText(
            frame, count_text, (text_x, text_y),
            self.counter_font, self.counter_font_scale,
            (0, 255, 255), self.counter_font_thickness, cv2.LINE_AA  # Cyan color for visibility
        )
        
        return frame
    
    def draw_detections(
        self, 
        frame: np.ndarray, 
        boxes: np.ndarray, 
        track_ids: List[int]
    ) -> np.ndarray:
        """
        Draw bounding boxes for detected livestock.
        
        Args:
            frame: Input BGR frame.
            boxes: Array of bounding box coordinates (x1, y1, x2, y2).
            track_ids: List of track IDs corresponding to each box.
        
        Returns:
            Frame with drawn bounding boxes.
        """
        for box, track_id in zip(boxes, track_ids):
            color = self.get_track_color(track_id)
            x1, y1, x2, y2 = map(int, box[:4])
            
            # Draw bounding box (no label)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, self.line_thickness)
        
        return frame
    
    def process_frame(
        self, 
        frame: np.ndarray,
        result
    ) -> Tuple[np.ndarray, int]:
        """
        Process a single frame with tracking results.
        
        Args:
            frame: Input BGR frame.
            result: YOLO tracking result for the frame.
        
        Returns:
            Tuple of (annotated frame, livestock count).
        """
        boxes = result.boxes
        livestock_count = len(boxes) if boxes is not None else 0
        
        annotated_frame = frame.copy()
        
        if boxes is not None and len(boxes) > 0:
            xyxy = boxes.xyxy.cpu().numpy()
            
            if boxes.id is not None:
                track_ids = boxes.id.cpu().numpy().astype(int).tolist()
            else:
                track_ids = list(range(len(boxes)))
            
            # Draw detections
            annotated_frame = self.draw_detections(annotated_frame, xyxy, track_ids)
        
        # Draw counter
        annotated_frame = self.draw_counter(annotated_frame, livestock_count)
        
        return annotated_frame, livestock_count
    
    def track_video(
        self,
        video_path: str,
        output_dir: str = "results",
        show_preview: bool = False
    ) -> str:
        """
        Track livestock in a video file.
        
        Args:
            video_path: Path to the input video file.
            output_dir: Directory to save the output video.
            show_preview: Whether to show a preview window during processing.
        
        Returns:
            Path to the output video file.
        """
        # Validate video path
        video_path = Path(video_path)
        if not video_path.exists():
            raise FileNotFoundError(f"Video file not found: {video_path}")
        
        # Create output directory
        output_dir = Path(output_dir)
        output_dir.mkdir(parents=True, exist_ok=True)
        
        # Generate output filename
        output_filename = f"{video_path.stem}_tracked{video_path.suffix}"
        output_path = output_dir / output_filename
        
        # Reset track colors for new video
        self.reset_tracks()
        
        # Get video properties
        cap = cv2.VideoCapture(str(video_path))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        cap.release()
        
        print(f"Video properties: {width}x{height} @ {fps}fps, {total_frames} frames")
        
        # Initialize video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(str(output_path), fourcc, fps, (width, height))
        
        # Run tracking
        print("Starting livestock tracking...")
        results = self.model.track(
            source=str(video_path),
            conf=self.conf_threshold,
            iou=self.iou_threshold,
            stream=True,
            persist=True,
            verbose=False
        )
        
        # Reopen video for frame reading
        cap = cv2.VideoCapture(str(video_path))
        
        frame_count = 0
        for result in results:
            ret, frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            
            # Process frame
            annotated_frame, _ = self.process_frame(frame, result)
            
            # Write frame to output
            out.write(annotated_frame)
            
            # Show preview if requested
            if show_preview:
                # Resize for display if too large
                display_frame = annotated_frame
                if width > 1920:
                    scale = 1920 / width
                    display_frame = cv2.resize(
                        annotated_frame, 
                        (int(width * scale), int(height * scale))
                    )
                cv2.imshow("Livestock Tracking", display_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            
            # Progress update
            if frame_count % 30 == 0:
                print(f"Processed {frame_count}/{total_frames} frames...")
        
        # Cleanup
        cap.release()
        out.release()
        if show_preview:
            cv2.destroyAllWindows()
        
        print(f"\nTracking complete!")
        print(f"Output saved to: {output_path}")
        print(f"Total unique tracks: {len(self.track_colors)}")
        
        return str(output_path)
    
    def track_single_frame(
        self,
        frame: np.ndarray
    ) -> Tuple[np.ndarray, int]:
        """
        Track livestock in a single frame.
        
        Note: For continuous tracking across frames, use track_video() instead.
        This method is useful for custom video processing pipelines.
        
        Args:
            frame: Input BGR frame.
        
        Returns:
            Tuple of (annotated frame, livestock count).
        """
        results = self.model.track(
            source=frame,
            conf=self.conf_threshold,
            iou=self.iou_threshold,
            persist=True,
            verbose=False,
            track_high_thresh=0.5,         # Primary detection threshold
            track_low_thresh=0.1,          # Secondary low-score matching
            track_buffer=120,              # Frames to keep lost tracks (4s @30fps)
            match_thresh=0.8               # IoU threshold for associations
        )
        
        return self.process_frame(frame, results[0])
    
    def set_counter_style(
        self,
        font_scale: float = 2.0,
        font_thickness: int = 4,
        padding: int = 25
    ):
        """
        Customize the counter display style.
        
        Args:
            font_scale: Scale factor for the font size.
            font_thickness: Thickness of the font.
            padding: Padding from the edge of the frame.
        """
        self.counter_font_scale = font_scale
        self.counter_font_thickness = font_thickness
        self.counter_padding = padding
    
    def __repr__(self) -> str:
        return (
            f"LivestockTracker("
            f"model='{self.model_path.name}', "
            f"conf={self.conf_threshold}, "
            f"iou={self.iou_threshold}, "
            f"tracks={len(self.track_colors)})"
        )

# %%
monitor = LivestockMonitor(
        model_path=r"runs\detect\train\weights\best.pt",
        conf_threshold=0.5,
        iou_threshold=0.8,
        line_thickness=3
    )
# Out:
# Loading RT-DETR model from: runs\detect\train\weights\best.pt

# %%
output = monitor.track_video(
        video_path=r"livestocks_sample_video\sample3.mp4",
        output_dir="results",
        show_preview=False
    )
    
print(f"\nOutput video: {output}")
print(f"Tracker info: {monitor}")
# Out:
# Video properties: 3840x2160 @ 23fps, 592 frames
# Starting livestock tracking...
# Processed 30/592 frames...
# Processed 60/592 frames...
# Processed 90/592 frames...
# Processed 120/592 frames...
# Processed 150/592 frames...
# Processed 180/592 frames...
# Processed 210/592 frames...
# Processed 240/592 frames...
# Processed 270/592 frames...
# Processed 300/592 frames...
# Processed 330/592 frames...
# Processed 360/592 frames...
# Processed 390/592 frames...
# Processed 420/592 frames...
# Processed 450/592 frames...
# Processed 480/592 frames...
# Processed 510/592 frames...
# Processed 540/592 frames...
# Processed 570/592 frames...
#
# Tracking complete!
# Output saved to: results\sample3_tracked.mp4
# Total unique tracks: 217
#
# Output video: results\sample3_tracked.mp4
# Tracker info: LivestockTracker(model='best.pt', conf=0.5, iou=0.8, tracks=217)

# %% [markdown]
# ---
#
# ## 👨‍💻 About Labellerr's Hands-On Learning in Computer Vision
#
# Thank you for exploring this **Labellerr Hands-On Computer Vision Cookbook**! We hope this notebook helped you learn, prototype, and accelerate your vision projects.
# Labellerr provides ready-to-run Jupyter/Colab notebooks for the latest models and real-world use cases in computer vision, AI agents, and data annotation.
#
# ---
# ## 🧑‍🔬 Check Our Popular Youtube Videos
#
# Whether you're a beginner or a practitioner, our hands-on training videos are perfect for learning custom model building, computer vision techniques, and applied AI:
#
# - [How to Fine-Tune YOLO on Custom Dataset](https://www.youtube.com/watch?v=pBLWOe01QXU)
#   Step-by-step guide to fine-tuning YOLO for real-world use—environment setup, annotation, training, validation, and inference.
# - [Build a Real-Time Intrusion Detection System with YOLO](https://www.youtube.com/watch?v=kwQeokYDVcE)
#   Create an AI-powered system to detect intruders in real time using YOLO and computer vision.
# - [Finding Athlete Speed Using YOLO](https://www.youtube.com/watch?v=txW0CQe_pw0)
#   Estimate real-time speed of athletes for sports analytics.
# - [Object Counting Using AI](https://www.youtube.com/watch?v=smsjBBQcIUQ)
#   Learn dataset curation, annotation, and training for robust object counting AI applications.
# ---
#
# ## 🎦 Popular Labellerr YouTube Videos
#
# Level up your skills and see video walkthroughs of these tools and notebooks on the
# [Labellerr YouTube Channel](https://www.youtube.com/@Labellerr/videos):
#
# - [How I Fixed My Biggest Annotation Nightmare with Labellerr](https://www.youtube.com/watch?v=hlcFdiuz_HI) – Solving complex annotation for ML engineers.
# - [Explore Your Dataset with Labellerr's AI](https://www.youtube.com/watch?v=LdbRXYWVyN0) – Auto-tagging, object counting, image descriptions, and dataset exploration.
# - [Boost AI Image Annotation 10X with Labellerr's CLIP Mode](https://www.youtube.com/watch?v=pY_o4EvYMz8) – Refine annotations with precision using CLIP mode.
# - [Boost Data Annotation Accuracy and Efficiency with Active Learning](https://www.youtube.com/watch?v=lAYu-ewIhTE) – Speed up your annotation workflow using Active Learning.
#
# > 👉 **Subscribe** for Labellerr's deep learning, annotation, and AI tutorials, or watch videos directly alongside notebooks!
#
# ---
#
# ## 🤝 Stay Connected
#
# - **Website:** [https://www.labellerr.com/](https://www.labellerr.com/)
# - **Blog:** [https://www.labellerr.com/blog/](https://www.labellerr.com/blog/)
# - **GitHub:** [Labellerr/Hands-On-Learning-in-Computer-Vision](https://github.com/Labellerr/Hands-On-Learning-in-Computer-Vision)
# - **LinkedIn:** [Labellerr](https://in.linkedin.com/company/labellerr)
# - **Twitter/X:** [@Labellerr1](https://x.com/Labellerr1)
#
# *Happy learning and building with Labellerr!*

# %% [markdown]
# [![Labellerr](https://storage.googleapis.com/labellerr-cdn/%200%20Labellerr%20template/notebook.webp)](https://www.labellerr.com)
#
# # **Egg Cell Detection using YOLO**
#
# ---
#
# [![labellerr](https://img.shields.io/badge/Labellerr-BLOG-black.svg)](https://www.labellerr.com/blog/<BLOG_NAME>)
# [![Youtube](https://img.shields.io/badge/Labellerr-YouTube-b31b1b.svg)](https://www.youtube.com/@Labellerr)
# [![Github](https://img.shields.io/badge/Labellerr-GitHub-green.svg)](https://github.com/Labellerr/Hands-On-Learning-in-Computer-Vision)

# %% [markdown]
# This notebook presents a **complete pipeline** for detecting and tracking egg cells from microscopic video footage using deep learning, specifically the **YOLO segmentation model**. Its workflow is designed for biologists, computer vision researchers, and ML engineers interested in automated analysis of cell videos.

# %% [markdown]
# ## 1. Cloning YOLO Utilities Repository
# **Command:**

# %%
# !git clone https://github.com/Labellerr/yolo_finetune_utils.git
# Out:
# Cloning into 'yolo_finetune_utils'...

# %% [markdown]
# **Purpose:**
# This cell clones a specialized YOLO fine-tuning utility repository from GitHub. These scripts offer handy functions to help with annotation conversion and dataset setup.
#
# ---
#
# ## 2. Importing YOLO Conversion Utility
# **Command:**

# %%
from yolo_finetune_utils.video_annotation.yolo_converter import convert_to_yolo_segmentation

# %% [markdown]
# **Purpose:**
# Imports a function that will later be used to convert custom video/book annotation data to the YOLO segmentation format required for training.
#
# ---
#
# ## 3. Converting JSON Annotations to YOLO Dataset
# **Command:**

# %%
ANNOTATION_FILE = "annotations.json"
VIDEOS_DIRECTORY = "video"
OUTPUT_DATASET_DIR = "yolo_dataset"


convert_to_yolo_segmentation(
    annotation_path=ANNOTATION_FILE,
    videos_dir=VIDEOS_DIRECTORY,
    use_split=True,
    split_ratio=(0.9, 0.1, 0.0),
    output_dir=OUTPUT_DATASET_DIR
)
# Out:
# Using split ratio: Train=0.9, Val=0.1, Test=0.0
# Creating output directory structure in: yolo_dataset
# Loading JSON annotation file...
# Found classes: ['Egg']
# Aggregating annotations from JSON...
# Processing files in JSON: 100%|██████████| 1/1 [00:00<00:00, 22.64it/s]
# Extracting frames and saving to YOLO format...
# Processing train set (267 frames)...
# Exporting train set: 100%|██████████| 267/267 [00:08<00:00, 31.79it/s]
# Processing val set (30 frames)...
# Exporting val set: 100%|██████████| 30/30 [00:01<00:00, 22.86it/s]
# No frames to process for the 'test' set.
#
# Creating data.yaml file...
#
# Conversion complete! ✨
# Dataset saved to: d:\Professional\Projects\Egg_cell_detection_using_YOLO\yolo_dataset
# YAML file saved to: d:\Professional\Projects\Egg_cell_detection_using_YOLO\yolo_dataset\data.yaml

# %% [markdown]
# **Purpose:**
# Transforms annotation data in JSON format into a YOLO-compatible dataset. It also splits the data (90% training, 10% validation, 0% test) and organizes it for training.
#
# ---
#
# ## 4. Emptying GPU Cache (PyTorch)
# **Command:**

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# **Purpose:**
# Clears the GPU memory cache, freeing up RAM for future model training or inference runs.
#
# ---
#
# ## 5. Monitoring GPU Status
# **Command:**

# %%
# !nvidia-smi
# Out:
# Mon Nov 10 16:02:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.57                 Driver Version: 581.57         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P4             12W /   49W |     808MiB /   8151MiB |     12%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           20532    C+G   ...bs-studio\bin\64bit\obs64.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **Purpose:**
# Displays key details about the current GPU hardware: memory usage, active processes, CUDA software version, and more.
#
# ---
#
# ## 6. Checking GPU Memory (PyTorch)
# **Command:**

# %%
# Check GPU memory status
print(f"Allocated: {torch.cuda.memory_allocated(0)/1024**3:.2f} GB")
print(f"Cached: {torch.cuda.memory_reserved(0)/1024**3:.2f} GB")
print(f"Free: {torch.cuda.mem_get_info(0)[0]/1024**3:.2f} GB")
# Out:
# Allocated: 0.00 GB
# Cached: 0.00 GB
# Free: 6.78 GB

# %% [markdown]
# **Purpose:**
# Shows how much GPU memory is currently allocated, cached, and free, helping debug memory errors and optimize resource usage.
#
# ---
#
# ## 7. Importing Ultralytics YOLO Framework
# **Command:**

# %%
from ultralytics import YOLO

# %% [markdown]
# **Purpose:**
# Imports the latest YOLO implementation from Ultralytics, enabling model loading, training, inference, and much more.
#
# ---
#
# ## 8. Training YOLO Segmentation Model
# **Command:**

# %%
# Load a model
model = YOLO("yolo11n-seg.pt")

# Train the model
results = model.train(
    data=r"d:\Professional\Projects\Egg_cell_detection_using_YOLO\yolo_dataset\data.yaml",    # Path to your dataset YAML file
    epochs=150,                        # Number of training epochs
    imgsz=640,                         # Image size
    batch=-1,                          # Batch size
    device=0,                          # GPU device (0 for first GPU, 'cpu' for CPU)
    workers=4,                         # Number of dataloader workers
)

# %% [markdown]
# **Purpose:**
# Loads a YOLO-v11 segmentation model and trains on your custom dataset for 150 epochs.
# Key details: image size 640px, GPU device 0, using the dataset you organized earlier.
#
# ---
#
# ## 9. Running Inference & Extracting Results
# **Command:**

# %%
model = YOLO(r"runs\segment\train\weights\best.pt")

# Run inference on video
results = model.track(
    source=r"video\embryo.mp4",
    save=True,
    conf=0.25,
    iou=0.7,
    show=True,
    show_labels=False
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 59.6ms
# video 1/1 (frame 2/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 49.6ms
# video 1/1 (frame 3/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 60.6ms
# video 1/1 (frame 4/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 56.1ms
# video 1/1 (frame 5/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 59.9ms
# video 1/1 (frame 6/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 47.0ms
# video 1/1 (frame 7/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 53.4ms
# video 1/1 (frame 8/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 61.5ms
# video 1/1 (frame 9/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 52.6ms
# video 1/1 (frame 10/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.4ms
# video 1/1 (frame 11/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 12/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.1ms
# video 1/1 (frame 13/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.9ms
# video 1/1 (frame 14/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.4ms
# video 1/1 (frame 15/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.5ms
# video 1/1 (frame 16/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 17/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.5ms
# video 1/1 (frame 18/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.3ms
# video 1/1 (frame 19/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 17.2ms
# video 1/1 (frame 20/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 18.1ms
# video 1/1 (frame 21/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.8ms
# video 1/1 (frame 22/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.9ms
# video 1/1 (frame 23/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 24/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 16.5ms
# video 1/1 (frame 25/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.0ms
# video 1/1 (frame 26/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 16.0ms
# video 1/1 (frame 27/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.4ms
# video 1/1 (frame 28/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 17.1ms
# video 1/1 (frame 29/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 30/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.4ms
# video 1/1 (frame 31/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 32/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 33/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 34/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 35/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.7ms
# video 1/1 (frame 36/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 37/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 9.9ms
# video 1/1 (frame 38/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.5ms
# video 1/1 (frame 39/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 40/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.6ms
# video 1/1 (frame 41/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 42/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 43/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 44/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 45/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 46/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.2ms
# video 1/1 (frame 47/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 48/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 49/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 50/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 16.7ms
# video 1/1 (frame 51/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 52/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.3ms
# video 1/1 (frame 53/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 54/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 55/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 17.5ms
# video 1/1 (frame 56/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 18.9ms
# video 1/1 (frame 57/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.2ms
# video 1/1 (frame 58/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.7ms
# video 1/1 (frame 59/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.3ms
# video 1/1 (frame 60/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 61/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.6ms
# video 1/1 (frame 62/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.0ms
# video 1/1 (frame 63/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 64/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.5ms
# video 1/1 (frame 65/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 66/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.2ms
# video 1/1 (frame 67/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.6ms
# video 1/1 (frame 68/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.7ms
# video 1/1 (frame 69/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.1ms
# video 1/1 (frame 70/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 71/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.4ms
# video 1/1 (frame 72/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.4ms
# video 1/1 (frame 73/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.2ms
# video 1/1 (frame 74/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.0ms
# video 1/1 (frame 75/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.2ms
# video 1/1 (frame 76/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 77/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 78/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 17.7ms
# video 1/1 (frame 79/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 80/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 19.3ms
# video 1/1 (frame 81/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.7ms
# video 1/1 (frame 82/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 83/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.5ms
# video 1/1 (frame 84/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.5ms
# video 1/1 (frame 85/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.4ms
# video 1/1 (frame 86/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.2ms
# video 1/1 (frame 87/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 88/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 89/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 90/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 91/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 92/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 93/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 94/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.5ms
# video 1/1 (frame 95/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 96/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 97/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 98/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 99/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 100/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.9ms
# video 1/1 (frame 101/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 102/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.8ms
# video 1/1 (frame 103/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.4ms
# video 1/1 (frame 104/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.0ms
# video 1/1 (frame 105/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 106/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 107/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 108/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 109/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 110/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.5ms
# video 1/1 (frame 111/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 112/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 113/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 114/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 115/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 116/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.2ms
# video 1/1 (frame 117/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 118/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.0ms
# video 1/1 (frame 119/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.2ms
# video 1/1 (frame 120/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 121/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 122/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 123/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 16.3ms
# video 1/1 (frame 124/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 125/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 126/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 127/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 128/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 129/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 130/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 131/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 132/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.7ms
# video 1/1 (frame 133/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 134/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.5ms
# video 1/1 (frame 135/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 136/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 137/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 138/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 139/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 140/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 141/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.0ms
# video 1/1 (frame 142/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.8ms
# video 1/1 (frame 143/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 144/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 145/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 146/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 147/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 148/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 149/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 150/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.6ms
# video 1/1 (frame 151/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.2ms
# video 1/1 (frame 152/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.5ms
# video 1/1 (frame 153/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 154/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.6ms
# video 1/1 (frame 155/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 156/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.4ms
# video 1/1 (frame 157/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.9ms
# video 1/1 (frame 158/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 19.2ms
# video 1/1 (frame 159/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.0ms
# video 1/1 (frame 160/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.7ms
# video 1/1 (frame 161/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 162/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.7ms
# video 1/1 (frame 163/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 164/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 165/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 166/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.5ms
# video 1/1 (frame 167/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 168/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 169/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.9ms
# video 1/1 (frame 170/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 171/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.7ms
# video 1/1 (frame 172/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 173/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 174/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.2ms
# video 1/1 (frame 175/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 176/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 177/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 178/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 179/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 180/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 181/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.2ms
# video 1/1 (frame 182/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.5ms
# video 1/1 (frame 183/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 184/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 185/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 186/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 187/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 188/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 189/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.3ms
# video 1/1 (frame 190/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 191/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 192/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 193/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.7ms
# video 1/1 (frame 194/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 195/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 196/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.0ms
# video 1/1 (frame 197/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 198/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 199/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 200/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.5ms
# video 1/1 (frame 201/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 202/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 203/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 204/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.3ms
# video 1/1 (frame 205/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 206/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.1ms
# video 1/1 (frame 207/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.4ms
# video 1/1 (frame 208/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.8ms
# video 1/1 (frame 209/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 210/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.4ms
# video 1/1 (frame 211/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.5ms
# video 1/1 (frame 212/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 213/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.9ms
# video 1/1 (frame 214/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 215/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.5ms
# video 1/1 (frame 216/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 217/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 218/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.4ms
# video 1/1 (frame 219/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.8ms
# video 1/1 (frame 220/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 221/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 222/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 223/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.8ms
# video 1/1 (frame 224/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.7ms
# video 1/1 (frame 225/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 226/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.4ms
# video 1/1 (frame 227/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 228/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 229/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 230/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.5ms
# video 1/1 (frame 231/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 232/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 233/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.7ms
# video 1/1 (frame 234/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 235/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 236/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 237/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 238/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.9ms
# video 1/1 (frame 239/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.8ms
# video 1/1 (frame 240/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 241/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.2ms
# video 1/1 (frame 242/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 243/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 244/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 245/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 246/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 247/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 248/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.4ms
# video 1/1 (frame 249/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.2ms
# video 1/1 (frame 250/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.9ms
# video 1/1 (frame 251/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.0ms
# video 1/1 (frame 252/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.4ms
# video 1/1 (frame 253/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.8ms
# video 1/1 (frame 254/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 255/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.2ms
# video 1/1 (frame 256/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 257/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.8ms
# video 1/1 (frame 258/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 259/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.3ms
# video 1/1 (frame 260/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.0ms
# video 1/1 (frame 261/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.3ms
# video 1/1 (frame 262/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 263/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.8ms
# video 1/1 (frame 264/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 265/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 266/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 267/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.5ms
# video 1/1 (frame 268/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 269/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 270/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.1ms
# video 1/1 (frame 271/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.6ms
# video 1/1 (frame 272/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.3ms
# video 1/1 (frame 273/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 274/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.0ms
# video 1/1 (frame 275/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.8ms
# video 1/1 (frame 276/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 277/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.9ms
# video 1/1 (frame 278/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.6ms
# video 1/1 (frame 279/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.6ms
# video 1/1 (frame 280/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.9ms
# video 1/1 (frame 281/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.3ms
# video 1/1 (frame 282/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.7ms
# video 1/1 (frame 283/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.1ms
# video 1/1 (frame 284/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 285/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.8ms
# video 1/1 (frame 286/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 15.4ms
# video 1/1 (frame 287/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.1ms
# video 1/1 (frame 288/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.9ms
# video 1/1 (frame 289/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.0ms
# video 1/1 (frame 290/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 12.0ms
# video 1/1 (frame 291/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.3ms
# video 1/1 (frame 292/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.5ms
# video 1/1 (frame 293/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.6ms
# video 1/1 (frame 294/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 14.8ms
# video 1/1 (frame 295/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 11.7ms
# video 1/1 (frame 296/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 13.6ms
# video 1/1 (frame 297/297) d:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4: 480x640 3 Eggs, 10.7ms
# Speed: 2.5ms preprocess, 14.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to D:\Professional\Projects\Egg_cell_detection_using_YOLO\runs\segment\track

# %% [markdown]
# **Purpose:**
# Runs inference with streaming output (frame-by-frame) so as to avoid RAM issues.
# Collects bounding boxes, segmentation masks, and class probabilities for downstream processing.
#
# ---
#
# ## 10. Egg Cell Tracker Class Definition
# **Command:**

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from collections import defaultdict
import colorsys


class EggCellTracker:
    """
    A class for tracking and visualizing microscopic egg cells using YOLO segmentation.
    
    Features:
    - Object tracking across frames
    - Segmentation mask visualization with unique colors
    - Distance measurement between nearby objects
    """
    
    def __init__(self, model_path, distance_threshold=300):
        """
        Initialize the tracker.
        
        Args:
            model_path (str): Path to the YOLO model
            distance_threshold (int): Maximum distance to draw lines between objects (default: 300)
        """
        self.model = YOLO(model_path)
        self.distance_threshold = distance_threshold
        self.track_colors = {}
        self.track_history = defaultdict(list)
        
    def generate_color(self, track_id):
        """Generate a unique color for each track ID."""
        if track_id not in self.track_colors:
            # Generate distinct colors using HSV color space
            hue = (track_id * 0.618033988749895) % 1.0  # Golden ratio for better distribution
            rgb = colorsys.hsv_to_rgb(hue, 0.8, 0.95)
            self.track_colors[track_id] = tuple(int(c * 255) for c in rgb)
        return self.track_colors[track_id]
    
    def calculate_centroid(self, mask):
        """Calculate the centroid of a segmentation mask."""
        moments = cv2.moments(mask)
        if moments["m00"] != 0:
            cx = int(moments["m10"] / moments["m00"])
            cy = int(moments["m01"] / moments["m00"])
            return (cx, cy)
        return None
    
    def calculate_distance(self, point1, point2):
        """Calculate Euclidean distance between two points."""
        return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)
    
    def draw_segmentation_mask(self, frame, mask, color, alpha=0.5):
        """Draw a colored segmentation mask on the frame."""
        colored_mask = np.zeros_like(frame, dtype=np.uint8)
        colored_mask[mask > 0] = color
        
        # Blend the mask with the original frame
        frame = cv2.addWeighted(frame, 1, colored_mask, alpha, 0)
        
        # Draw contour for better visibility
        contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(frame, contours, -1, color, 2)
        
        return frame
    
    def draw_distance_lines(self, frame, centroids, colors):
        """Draw lines between nearby objects with distance labels."""
        centroid_list = list(centroids.items())
        lines_drawn = 0
        
        for i in range(len(centroid_list)):
            for j in range(i + 1, len(centroid_list)):
                track_id1, center1 = centroid_list[i]
                track_id2, center2 = centroid_list[j]
                
                distance = self.calculate_distance(center1, center2)
                
                if distance <= self.distance_threshold:
                    # Draw line between centroids with thicker line
                    cv2.line(frame, center1, center2, (0, 255, 255), 3)  # Yellow line, thicker
                    
                    # Calculate midpoint for distance label
                    mid_x = (center1[0] + center2[0]) // 2
                    mid_y = (center1[1] + center2[1]) // 2
                    
                    # Draw distance text with background
                    distance_text = f"{distance:.1f}px"
                    (text_width, text_height), baseline = cv2.getTextSize(
                        distance_text, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2
                    )
                    
                    # Draw background rectangle
                    cv2.rectangle(frame,
                                (mid_x - 2, mid_y - text_height - 2),
                                (mid_x + text_width + 2, mid_y + baseline + 2),
                                (0, 0, 0), -1)
                    
                    # Draw text
                    cv2.putText(frame, distance_text, (mid_x, mid_y),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
                    
                    lines_drawn += 1
        
        return frame, lines_drawn
    
    def process_video(self, video_path, output_path=None, show_preview=True, draw_distance_lines=True):
        """
        Process a video file and track egg cells.
        
        Args:
            video_path (str): Path to input video
            output_path (str): Path to save output video (optional)
            show_preview (bool): Whether to show live preview
        """
        cap = cv2.VideoCapture(video_path)
        
        # Get video properties
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        
        # Initialize video writer if output path is provided
        writer = None
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        frame_count = 0
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            
            # Run tracking
            results = self.model.track(frame, persist=True, verbose=False)
            
            # Create a copy for annotation
            annotated_frame = frame.copy()
            
            # Store centroids for distance calculation
            current_centroids = {}
            current_colors = {}
            
            if results[0].masks is not None and results[0].boxes.id is not None:
                # Get masks and track IDs
                masks = results[0].masks.data.cpu().numpy()
                track_ids = results[0].boxes.id.cpu().numpy().astype(int)
                
                # Process each detection
                for mask, track_id in zip(masks, track_ids):
                    # Resize mask to frame size
                    mask_resized = cv2.resize(mask, (width, height))
                    mask_binary = (mask_resized > 0.5).astype(np.uint8)
                    
                    # Generate color for this track
                    color = self.generate_color(track_id)
                    current_colors[track_id] = color
                    
                    # Draw segmentation mask
                    annotated_frame = self.draw_segmentation_mask(
                        annotated_frame, mask_binary, color
                    )
                    
                    # Calculate and store centroid
                    centroid = self.calculate_centroid(mask_binary)
                    if centroid:
                        current_centroids[track_id] = centroid
                        
                        # Draw centroid point
                        cv2.circle(annotated_frame, centroid, 5, color, -1)
                        cv2.circle(annotated_frame, centroid, 5, (255, 255, 255), 2)
                        
                        # Draw track ID with background
                        label = f"ID:{track_id}"
                        label_x = centroid[0] + 10
                        label_y = centroid[1] - 10
                        
                        # Get text size for background rectangle
                        (text_width, text_height), baseline = cv2.getTextSize(
                            label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2
                        )
                        
                        # Draw background rectangle with track color
                        cv2.rectangle(annotated_frame, 
                                    (label_x - 2, label_y - text_height - 2),
                                    (label_x + text_width + 2, label_y + baseline + 2),
                                    color, -1)
                        
                        # Draw white text on colored background
                        cv2.putText(annotated_frame, label, 
                                  (label_x, label_y),
                                  cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            
            # Draw distance lines between nearby objects
            if draw_distance_lines:
                lines_drawn = 0
                if len(current_centroids) > 1:
                    annotated_frame, lines_drawn = self.draw_distance_lines(
                        annotated_frame, current_centroids, current_colors
                    )
            
            # Add object counter and lines info
            cv2.putText(annotated_frame, f"Egg Cells: {len(current_centroids)}", (10, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
            
            # Write frame
            if writer:
                writer.write(annotated_frame)
            
            # Show preview
            if show_preview:
                cv2.imshow('Egg Cell Tracking', annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
        
        # Cleanup
        cap.release()
        if writer:
            writer.release()
        if show_preview:
            cv2.destroyAllWindows()
        
        print(f"Processing complete! Total frames: {frame_count}")
        print(f"Total unique tracks: {len(self.track_colors)}")

# %% [markdown]
# **Purpose:**
# Defines the main class for post-processing YOLO outputs: tracks segmented egg cells across frames, annotates videos, manages object IDs, and calculates movement or proximity between detected cells.
#
# ---
#
# ## 11. Using the Egg Cell Tracker (Example)
# **Command:**

# %%
# Example usage
if __name__ == "__main__":
    # Initialize tracker
    tracker = EggCellTracker(
        model_path=r"D:\Professional\Projects\Egg_cell_detection_using_YOLO\runs\segment\train\weights\best.pt",
        distance_threshold=500  # Adjust based on your needs
    )
    
    # Process video
    tracker.process_video(
        video_path=r"D:\Professional\Projects\Egg_cell_detection_using_YOLO\video\embryo.mp4",
        output_path="egg_cell_detection.mp4",
        show_preview=True,
        draw_distance_lines=False
    )
# Out:
# Processing complete! Total frames: 297
# Total unique tracks: 3

# %% [markdown]
# **Purpose:**
# Demonstrates how to initialize the custom tracker with trained weights, set cell-tracking distance, analyze a raw micro-video, and produce a fully annotated output file.
#
# ---
#
# *This notebook sets up, trains, and analyzes fertile egg cells using advanced YOLO segmentation and custom video processing classes. Each section includes a code fragment and its intended role within the workflow.*
